# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import sklearn.preprocessing
from sklearn.model_selection import train_test_split

import env
from acquire import get_mall_data

# %%
df = get_mall_data()

# %%
df.head()
# Out:
#    Unnamed: 0  customer_id  gender  age  annual_income  spending_score
# 0           0            1    Male   19             15              39
# 1           1            2    Male   21             15              81
# 2           2            3  Female   20             16               6
# 3           3            4  Female   23             16              77
# 4           4            5  Female   31             17              40

# %%
df.drop(columns = "Unnamed: 0",inplace = True)

# %%
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
sns.pairplot(df)

# %%
sns.scatterplot(data = df,x = df.spending_score,y = df.annual_income,hue = df.age)
# Out:
# <AxesSubplot:xlabel='spending_score', ylabel='annual_income'>
